# %% [markdown]
# # The Gargantuas Video Editor - Google Colab Setup
#
# Complete setup with Python 3.11, GPU support, and all dependencies including background removal.
#
# **Run the cell below.**

# %%
# %cd /content
# !rm -rf The-Gargantuas-Video-Editor
# !rm -rf py311

# !apt-get update -y
# !apt-get install -y ffmpeg git curl python3.11 python3.11-venv python3.11-distutils

# !python3.11 -m venv /content/py311
# !/content/py311/bin/python -m pip install --upgrade pip setuptools wheel

# !git clone https://github.com/TheGargantuas/The-Gargantuas-Video-Editor.git
# %cd /content/The-Gargantuas-Video-Editor

# !/content/py311/bin/pip install --no-cache-dir numpy==1.26.4
# !/content/py311/bin/pip install --no-cache-dir torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2

print("Installing cryptography...")
# !/content/py311/bin/pip install --no-cache-dir cryptography==46.0.5

# !/content/py311/bin/pip install --no-cache-dir gradio opencv-python==4.9.0.80 opencv-python-headless==4.9.0.80 pillow ffmpeg-python python-dotenv

# !/content/py311/bin/pip install --no-cache-dir basicsr realesrgan gfpgan facexlib librosa soundfile scipy pydub

# !/content/py311/bin/pip install --no-cache-dir faster-whisper openai

print("Installing rembg for background removal...")
# !/content/py311/bin/pip install --no-cache-dir rembg==2.0.72 pymatting==1.1.15

print("Fixing dependency conflicts...")
# !/content/py311/bin/python -c "from utils.dependency_patch import fix_dependencies; fix_dependencies(verbose=True)"

print("Ensuring numpy<2 compatibility...")
# !/content/py311/bin/pip install --no-cache-dir "numpy>=1.24.4,<2"

# %env MPLBACKEND=Agg
# %env MATPLOTLIBRC=/tmp/matplotlibrc
# !printf "[matplotlib]\nbackend = Agg\n" > /tmp/matplotlibrc
# %env GRADIO_SHARE=true

print("\nLaunching The Gargantuas Video Editor...")
print("TIP: Use Groq API (100k tokens/day FREE) for subtitles: https://console.groq.com/keys")
print("TIP: Enable 'Single Pass' validation mode to save API quota\n")
# !/content/py311/bin/python main.py

# %% [markdown]
# # The Gargantuas Video Editor - Google Colab Setup
#
# Complete setup with Python 3.11, GPU support, and all dependencies.
#
# **Note:** Background removal feature included with automatic dependency fixes.
#
# **Run the cell below.**

# %%
# %cd /content
# !rm -rf The-Gargantuas-Video-Editor
# !rm -rf py311

# !apt-get update -y
# !apt-get install -y ffmpeg git curl python3.11 python3.11-venv python3.11-distutils

# !python3.11 -m venv /content/py311
# !/content/py311/bin/python -m pip install --upgrade pip setuptools wheel

# !git clone https://github.com/TheGargantuas/The-Gargantuas-Video-Editor.git
# %cd /content/The-Gargantuas-Video-Editor

# !/content/py311/bin/pip install --no-cache-dir numpy==1.26.4
# !/content/py311/bin/pip install --no-cache-dir torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2

print("Installing cryptography...")
# !/content/py311/bin/pip install --no-cache-dir cryptography==46.0.5

# !/content/py311/bin/pip install --no-cache-dir gradio opencv-python==4.9.0.80 opencv-python-headless==4.9.0.80 pillow ffmpeg-python python-dotenv

# !/content/py311/bin/pip install --no-cache-dir basicsr realesrgan gfpgan facexlib librosa soundfile scipy pydub

# !/content/py311/bin/pip install --no-cache-dir faster-whisper openai

print("Fixing dependency conflicts...")
# !/content/py311/bin/python -c "from utils.dependency_patch import fix_dependencies; fix_dependencies(verbose=True)"

# %env MPLBACKEND=Agg
# %env MATPLOTLIBRC=/tmp/matplotlibrc
# !printf "[matplotlib]\nbackend = Agg\n" > /tmp/matplotlibrc
# %env GRADIO_SHARE=true

print("\nLaunching The Gargantuas Video Editor...")
print("TIP: Use Groq API (100k tokens/day FREE) for subtitles: https://console.groq.com/keys")
print("TIP: Enable 'Single Pass' validation mode to save API quota\n")
# !/content/py311/bin/python main.py
